# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
from matplotlib import rc
rc("font",family= 'Malgun Gothic')

# %%
data = pd.read_csv('자료 조회_20230703.csv', encoding='euc-kr')

# %%
data
# Out:
#      측정소명       년/월/일   회차  수심(m)  수온(℃)  DO(㎎/L)  BOD(㎎/L)  COD(㎎/L)  \
# 0      구의  2023/01/02  1회차    NaN    NaN      NaN       NaN       NaN
# 1     노량진  2023/01/02  1회차    NaN    2.0     13.6       1.5       4.5
# 2    안양천9  2023/01/02  1회차    NaN    NaN      NaN       NaN       NaN
# 3    중랑천3  2023/01/02  1회차    NaN    NaN      NaN       NaN       NaN
# 4      가양  2023/01/03  1회차    NaN    NaN      NaN       NaN       NaN
# ..    ...         ...  ...    ...    ...      ...       ...       ...
# 226   초이천  2023/04/24  4회차   1.01   19.5     12.3       2.0       5.4
# 227    구의  2023/04/27  4회차    NaN   14.8     10.5       1.3       3.6
# 228   노량진  2023/04/27  4회차    NaN   16.4      9.6       2.0       4.5
# 229  안양천9  2023/04/27  4회차    NaN   16.4      8.6       3.9       9.0
# 230  중랑천3  2023/04/27  4회차    NaN   19.4     10.1       2.2       7.1
#
#      클로로필 a(㎎/㎥)  TN(㎎/L)  ...  벤젠(㎎/L)  폴리크로리네이티트비페닐(㎎/L)  유기인(㎎/L)  \
# ...

# %%
data.columns
# Out:
# Index(['측정소명', '년/월/일', '회차', '수심(m)', '수온(℃)', 'DO(㎎/L)', 'BOD(㎎/L)',
#        'COD(㎎/L)', '클로로필 a(㎎/㎥)', 'TN(㎎/L)', 'TP(㎎/L)', 'TOC(㎎/L)', '수소이온농도',
#        '페놀류(㎎/L)', '전기전도도(μS/㎝)', '총대장균군수(총대장균군수/100ml)', '카드뮴(㎎/L)',
#        '시안(㎎/L)', '납(㎎/L)', '6가크롬(㎎/L)', '비소(㎎/L)', '수은(㎎/L)', '구리(㎎/L)',
#        '아연(㎎/L)', '크롬(㎎/L)', '니켈(㎎/L)', '바륨(㎎/L)', '셀레늄(㎎/L)', '용존총질소(㎎/L)',
#        '암모니아성 질소(㎎/L)', '질산성 질소(㎎/L)', '용존총인(㎎/L)', '인산염인(㎎/L)', 'SS(㎎/L)',
#        '헥사클로로벤젠 (㎍/L)', '분원성대장균군수', '불소(㎎/L)', '색도(㎎/L)', '노말헥산추출물질(㎎/L)',
#        '용해성망간(㎎/L)', '용해성철(㎎/L)', '음이온계면활성제(㎎/L)', '트리클로로에틸렌 (㎎/L)',
#        '테트라클로로에틸렌(㎎/L)', '사염화탄소', '1.2-디클로로에탄(㎎/L)', '디클로로메탄(㎎/L)', '벤젠(㎎/L)',
#        '폴리크로리네이티트비페닐(㎎/L)', '유기인(㎎/L)', '안티몬 (㎎/L)', '클로로포름 (㎎/L)',
#        '디에틸헥실프탈레이트 (㎎/L)', '1.4-다이옥세인 (㎎/L)', '투명도(m)', '유량(㎥/s)',
#        '포름알데히드(㎎/L)'],
#       dtype='object')

# %% [markdown]
# # unique 값이 1 이하인 칼럼 모두 제거

# %%
unique_counts = data.nunique()
columns_to_drop = unique_counts[unique_counts <= 1].index
columns_to_drop
# Out:
# Index(['수은(㎎/L)', '구리(㎎/L)', '아연(㎎/L)', '크롬(㎎/L)', '니켈(㎎/L)', '바륨(㎎/L)',
#        '셀레늄(㎎/L)', '헥사클로로벤젠 (㎍/L)', '불소(㎎/L)', '색도(㎎/L)', '노말헥산추출물질(㎎/L)',
#        '용해성망간(㎎/L)', '용해성철(㎎/L)', '트리클로로에틸렌 (㎎/L)', '테트라클로로에틸렌(㎎/L)', '사염화탄소',
#        '1.2-디클로로에탄(㎎/L)', '디클로로메탄(㎎/L)', '벤젠(㎎/L)', '폴리크로리네이티트비페닐(㎎/L)',
#        '유기인(㎎/L)', '클로로포름 (㎎/L)', '디에틸헥실프탈레이트 (㎎/L)', '1.4-다이옥세인 (㎎/L)',
#        '투명도(m)', '포름알데히드(㎎/L)'],
#       dtype='object')

# %%
data = data.drop(columns_to_drop, axis=1)

# %%
data.columns
# Out:
# Index(['측정소명', '년/월/일', '회차', '수심(m)', '수온(℃)', 'DO(㎎/L)', 'BOD(㎎/L)',
#        'COD(㎎/L)', '클로로필 a(㎎/㎥)', 'TN(㎎/L)', 'TP(㎎/L)', 'TOC(㎎/L)', '수소이온농도',
#        '페놀류(㎎/L)', '전기전도도(μS/㎝)', '총대장균군수(총대장균군수/100ml)', '카드뮴(㎎/L)',
#        '시안(㎎/L)', '납(㎎/L)', '6가크롬(㎎/L)', '비소(㎎/L)', '용존총질소(㎎/L)',
#        '암모니아성 질소(㎎/L)', '질산성 질소(㎎/L)', '용존총인(㎎/L)', '인산염인(㎎/L)', 'SS(㎎/L)',
#        '분원성대장균군수', '음이온계면활성제(㎎/L)', '안티몬 (㎎/L)', '유량(㎥/s)'],
#       dtype='object')

# %%
for i in data.columns:
    print(data[i].unique())
# Out:
# ['구의' '노량진' '안양천9' '중랑천3' '가양' '고덕천' '도림천' '목감천1' '성내천' '성북천' '안양천10'
#  '양재천2' '우이천' '정릉천' '중랑천4' '중랑천5' '중랑천6' '청계천1' '청계천2' '청계천3' '탄천6' '홍제천'
#  '뚝도' '보광' '암사' '영등포' '잠실' '감이천' '망월천' '양재천1' '초이천' '목감천2' '안양천8']
# ['2023/01/02' '2023/01/03' '2023/01/05' '2023/01/10' '2023/01/12'
#  '2023/01/16' '2023/01/17' '2023/01/19' '2023/01/25' '2023/01/30'
#  '2023/02/01' '2023/02/02' '2023/02/06' '2023/02/14' '2023/02/15'
#  '2023/02/16' '2023/02/17' '2023/02/20' '2023/02/21' '2023/02/23'
#  '2023/02/27' '2023/03/02' '2023/03/06' '2023/03/07' '2023/03/09'
#  '2023/03/14' '2023/03/16' '2023/03/21' '2023/03/22' '2023/03/23'
#  '2023/03/24' '2023/03/27' '2023/03/30' '2023/04/04' '2023/04/06'
#  '2023/04/12' '2023/04/13' '2023/04/14' '2023/04/17' '2023/04/20'
#  '2023/04/21' '2023/04/24' '2023/04/27']
# ['1회차' '2회차' '3회차' '4회차' '5회차']
# [ nan 0.79 1.24 1.25 1.04 1.54 2.09 0.77 1.12 1.21 1.48 2.05 0.8  1.1
#  1.03 1.49 1.2  1.5  2.06 1.11 1.47 2.04 1.26 1.22 1.02 1.63 2.12 0.78
# ...

# %%
data = data.replace('정량한계미만', np.nan)

# %%
data.drop(['수심(m)','유량(㎥/s)'],axis=1,inplace=True)

# %%
unique_counts = data.nunique()
columns_to_drop = unique_counts[unique_counts <= 1].index
columns_to_drop
# Out:
# Index(['페놀류(㎎/L)', '카드뮴(㎎/L)', '시안(㎎/L)', '납(㎎/L)', '6가크롬(㎎/L)', '비소(㎎/L)',
#        '음이온계면활성제(㎎/L)', '안티몬 (㎎/L)'],
#       dtype='object')

# %%
data
# Out:
#      측정소명       년/월/일   회차  수온(℃)  DO(㎎/L)  BOD(㎎/L)  COD(㎎/L)  클로로필 a(㎎/㎥)  \
# 0      구의  2023/01/02  1회차    NaN      NaN       NaN       NaN          NaN
# 1     노량진  2023/01/02  1회차    2.0     13.6       1.5       4.5          9.3
# 2    안양천9  2023/01/02  1회차    NaN      NaN       NaN       NaN          NaN
# 3    중랑천3  2023/01/02  1회차    NaN      NaN       NaN       NaN          NaN
# 4      가양  2023/01/03  1회차    NaN      NaN       NaN       NaN          NaN
# ..    ...         ...  ...    ...      ...       ...       ...          ...
# 226   초이천  2023/04/24  4회차   19.5     12.3       2.0       5.4          NaN
# 227    구의  2023/04/27  4회차   14.8     10.5       1.3       3.6          NaN
# 228   노량진  2023/04/27  4회차   16.4      9.6       2.0       4.5         17.8
# 229  안양천9  2023/04/27  4회차   16.4      8.6       3.9       9.0          NaN
# 230  중랑천3  2023/04/27  4회차   19.4     10.1       2.2       7.1          NaN
#
# ...

# %%
data.columns
# Out:
# Index(['측정소명', '년/월/일', '회차', '수온(℃)', 'DO(㎎/L)', 'BOD(㎎/L)', 'COD(㎎/L)',
#        '클로로필 a(㎎/㎥)', 'TN(㎎/L)', 'TP(㎎/L)', 'TOC(㎎/L)', '수소이온농도', '페놀류(㎎/L)',
#        '전기전도도(μS/㎝)', '총대장균군수(총대장균군수/100ml)', '카드뮴(㎎/L)', '시안(㎎/L)', '납(㎎/L)',
#        '6가크롬(㎎/L)', '비소(㎎/L)', '용존총질소(㎎/L)', '암모니아성 질소(㎎/L)', '질산성 질소(㎎/L)',
#        '용존총인(㎎/L)', '인산염인(㎎/L)', 'SS(㎎/L)', '분원성대장균군수', '음이온계면활성제(㎎/L)',
#        '안티몬 (㎎/L)'],
#       dtype='object')

# %%
data = data[['측정소명', '년/월/일', '회차', '수온(℃)', 'DO(㎎/L)', 'BOD(㎎/L)', 'COD(㎎/L)','TN(㎎/L)', 'TP(㎎/L)', 'TOC(㎎/L)', '수소이온농도','SS(㎎/L)']]

# %%
data["COD(㎎/L)"].unique()
# Out:
# array([ nan,  4.5,  5.4,  3.2,  5.9,  3.8,  2. ,  8. ,  5. ,  2.7,  1.5,
#         5.1,  5.2,  6.8,  4.6,  6.5,  2.6,  4.7,  3.3,  4.2,  3.1,  8.9,
#         7.1,  4. ,  4.9,  4.3,  8.3,  4.1,  6. ,  2.3,  6.7,  2.5,  5.3,
#         6.6,  2.2,  2.4,  5.8,  5.6,  4.4,  5.7,  1.9,  6.3,  9.1,  7.5,
#         9.5, 10.1,  1.2,  7. ,  4.8, 10.6,  7.7,  6.4,  3.4,  7.8,  3. ,
#         7.2,  2.8, 10.9, 10.4, 12.4,  9.4, 10.5,  3.5, 11.1, 10. ,  7.4,
#         2.9, 12. ,  3.9, 10.8, 12.7,  8.4, 12.6,  6.1,  9.7,  8.8,  3.7,
#         6.2,  5.5, 10.3, 10.7, 13.6,  9.3,  3.6,  9. ])

# %%
def assign_score_bod(value):
    if value <= 5:
        return 0
    else:
        return 1

# lambda 함수에 함수 적용
data['BOD_score'] = data['BOD(㎎/L)'].apply(lambda x: assign_score_bod(x))
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\758294882.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['BOD_score'] = data['BOD(㎎/L)'].apply(lambda x: assign_score_bod(x))

# %%
print(data['BOD_score'].value_counts())
# Out:
# 0    194
# 1     37
# Name: BOD_score, dtype: int64

# %%
def assign_score_cod(value):
    if value <= 7:
        return 0
    else:
        return 1

# lambda 함수에 함수 적용
data['COD_score'] = data['COD(㎎/L)'].apply(lambda x: assign_score_cod(x))
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\258608780.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['COD_score'] = data['COD(㎎/L)'].apply(lambda x: assign_score_cod(x))

# %%
print(data['COD_score'].value_counts())
# Out:
# 0    154
# 1     77
# Name: COD_score, dtype: int64

# %%
def assign_score_toc(value):
     if value <= 5:
        return 0
     else:
        return 1

# lambda 함수에 함수 적용
data['TOC_score'] = data['TOC(㎎/L)'].apply(lambda x: assign_score_toc(x))
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\644123046.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['TOC_score'] = data['TOC(㎎/L)'].apply(lambda x: assign_score_toc(x))

# %%
print(data['TOC_score'].value_counts())
# Out:
# 0    180
# 1     51
# Name: TOC_score, dtype: int64

# %%
def assign_score_tp(value):
    if value <= 0.2:
        return 0
    else:
        return 1

# lambda 함수에 함수 적용
data['TP_score'] = data['TP(㎎/L)'].apply(lambda x: assign_score_tp(x))
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\1888322499.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['TP_score'] = data['TP(㎎/L)'].apply(lambda x: assign_score_tp(x))

# %%
def assign_score_ss(value):
    if value <= 25:
        return 0
   
    else:
        return 1

# lambda 함수에 함수 적용
data['ss_score'] = data['SS(㎎/L)'].apply(lambda x: assign_score_ss(x))
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\1430876141.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ss_score'] = data['SS(㎎/L)'].apply(lambda x: assign_score_ss(x))

# %%
def assign_score_do(value):
    if value >=5:
        return 0
   
    else:
        return 1

# lambda 함수에 함수 적용
data['do_score'] = data['DO(㎎/L)'].apply(lambda x: assign_score_do(x))
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\1091280832.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['do_score'] = data['DO(㎎/L)'].apply(lambda x: assign_score_do(x))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   측정소명       231 non-null    object
#  1   년/월/일      231 non-null    object
#  2   회차         231 non-null    object
#  3   수온(℃)      209 non-null    float64
#  4   DO(㎎/L)    209 non-null    float64
#  5   BOD(㎎/L)   209 non-null    float64
#  6   COD(㎎/L)   209 non-null    float64
#  7   TN(㎎/L)    209 non-null    float64
#  8   TP(㎎/L)    209 non-null    float64
#  9   TOC(㎎/L)   209 non-null    float64
#  10  수소이온농도     209 non-null    float64
#  11  SS(㎎/L)    209 non-null    float64
#  12  BOD_score  231 non-null    int64
#  13  COD_score  231 non-null    int64
#  14  TOC_score  231 non-null    int64
#  15  TP_score   231 non-null    int64
#  16  ss_score   231 non-null    int64
#  17  do_score   231 non-null    int64
# dtypes: float64(9), int64(6), object(3)
# memory usage: 32.6+ KB

# %%
data['pollution_score'] = (
    data['BOD_score'] +
    data['COD_score'] +
    data['TOC_score'] +
    data['TP_score'] +
    data['ss_score'] +
    data['do_score']
)
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\2311351349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pollution_score'] = (

# %%
data['pollution_score'].value_counts()
# Out:
# 0    146
# 2     26
# 6     22
# 1     19
# 3     15
# 4      3
# Name: pollution_score, dtype: int64

# %%
data.drop(['BOD_score','COD_score', 'TOC_score','TN(㎎/L)' ,'TP_score', 'ss_score', 'do_score'],axis=1,inplace=True)
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\2150463414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['BOD_score','COD_score', 'TOC_score','TN(㎎/L)' ,'TP_score', 'ss_score', 'do_score'],axis=1,inplace=True)

# %%
data
# Out:
#      측정소명       년/월/일   회차  수온(℃)  DO(㎎/L)  BOD(㎎/L)  COD(㎎/L)  TP(㎎/L)  \
# 0      구의  2023/01/02  1회차    NaN      NaN       NaN       NaN      NaN
# 1     노량진  2023/01/02  1회차    2.0     13.6       1.5       4.5    0.042
# 2    안양천9  2023/01/02  1회차    NaN      NaN       NaN       NaN      NaN
# 3    중랑천3  2023/01/02  1회차    NaN      NaN       NaN       NaN      NaN
# 4      가양  2023/01/03  1회차    NaN      NaN       NaN       NaN      NaN
# ..    ...         ...  ...    ...      ...       ...       ...      ...
# 226   초이천  2023/04/24  4회차   19.5     12.3       2.0       5.4    0.132
# 227    구의  2023/04/27  4회차   14.8     10.5       1.3       3.6    0.024
# 228   노량진  2023/04/27  4회차   16.4      9.6       2.0       4.5    0.048
# 229  안양천9  2023/04/27  4회차   16.4      8.6       3.9       9.0    0.165
# 230  중랑천3  2023/04/27  4회차   19.4     10.1       2.2       7.1    0.144
#
#      TOC(㎎/L)  수소이온농도  SS(㎎/L)  pollution_score
# 0         NaN     NaN      NaN                6
# ...

# %%
data['년/월/일'] = pd.to_datetime(data['년/월/일'])
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\1782319972.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['년/월/일'] = pd.to_datetime(data['년/월/일'])

# %%
data
# Out:
#      측정소명      년/월/일   회차  수온(℃)  DO(㎎/L)  BOD(㎎/L)  COD(㎎/L)  TP(㎎/L)  \
# 0      구의 2023-01-02  1회차    NaN      NaN       NaN       NaN      NaN
# 1     노량진 2023-01-02  1회차    2.0     13.6       1.5       4.5    0.042
# 2    안양천9 2023-01-02  1회차    NaN      NaN       NaN       NaN      NaN
# 3    중랑천3 2023-01-02  1회차    NaN      NaN       NaN       NaN      NaN
# 4      가양 2023-01-03  1회차    NaN      NaN       NaN       NaN      NaN
# ..    ...        ...  ...    ...      ...       ...       ...      ...
# 226   초이천 2023-04-24  4회차   19.5     12.3       2.0       5.4    0.132
# 227    구의 2023-04-27  4회차   14.8     10.5       1.3       3.6    0.024
# 228   노량진 2023-04-27  4회차   16.4      9.6       2.0       4.5    0.048
# 229  안양천9 2023-04-27  4회차   16.4      8.6       3.9       9.0    0.165
# 230  중랑천3 2023-04-27  4회차   19.4     10.1       2.2       7.1    0.144
#
#      TOC(㎎/L)  수소이온농도  SS(㎎/L)  pollution_score
# 0         NaN     NaN      NaN                6
# ...

# %%
import numpy as np
import pandas as pd

# %%
df_2023 = pd.read_csv('rainfall_2023.csv', encoding='cp949')

# %%
df_2023['지점명'].unique()
# Out:
# array(['관악(레)', '강남', '서초', '강동', '송파', '강서', '양천', '도봉', '노원', '동대문',
#        '중랑', '기상청', '마포', '서대문', '광진', '성북', '용산', '은평', '금천', '한강', '중구',
#        '성동', '구로', '강북', '남현', '관악', '영등포 ', '현충원'], dtype=object)

# %%
df = df_2023[~df_2023['지점명'].isin(['기상청', '한강', '남현', '현충원', '관악(레)'])]
df
# Out:
#          지점   지점명                일시  강수량(mm)
# 4311    400    강남  2023-01-01 00:00      0.0
# 4312    400    강남  2023-01-01 01:00      0.0
# 4313    400    강남  2023-01-01 02:00      0.0
# 4314    400    강남  2023-01-01 03:00      0.0
# 4315    400    강남  2023-01-01 04:00      0.0
# ...     ...   ...               ...      ...
# 116804  510  영등포   2023-06-30 19:00      0.0
# 116805  510  영등포   2023-06-30 20:00      0.0
# 116806  510  영등포   2023-06-30 21:00      0.0
# 116807  510  영등포   2023-06-30 22:00      0.0
# 116808  510  영등포   2023-06-30 23:00      0.0
#
# [99522 rows x 4 columns]

# %%
df['날짜'] = pd.to_datetime(df['일시']).dt.date
df
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\2787580731.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['날짜'] = pd.to_datetime(df['일시']).dt.date
#          지점   지점명                일시  강수량(mm)          날짜
# 4311    400    강남  2023-01-01 00:00      0.0  2023-01-01
# 4312    400    강남  2023-01-01 01:00      0.0  2023-01-01
# 4313    400    강남  2023-01-01 02:00      0.0  2023-01-01
# 4314    400    강남  2023-01-01 03:00      0.0  2023-01-01
# 4315    400    강남  2023-01-01 04:00      0.0  2023-01-01
# ...     ...   ...               ...      ...         ...
# 116804  510  영등포   2023-06-30 19:00      0.0  2023-06-30
# 116805  510  영등포   2023-06-30 20:00      0.0  2023-06-30
# ...

# %%
df['cum_rainfall'] = df.groupby(['지점명', '날짜'])['강수량(mm)'].cumsum()
df
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\1848631382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cum_rainfall'] = df.groupby(['지점명', '날짜'])['강수량(mm)'].cumsum()
#          지점   지점명                일시  강수량(mm)          날짜  cum_rainfall
# 4311    400    강남  2023-01-01 00:00      0.0  2023-01-01           0.0
# 4312    400    강남  2023-01-01 01:00      0.0  2023-01-01           0.0
# 4313    400    강남  2023-01-01 02:00      0.0  2023-01-01           0.0
# 4314    400    강남  2023-01-01 03:00      0.0  2023-01-01           0.0
# 4315    400    강남  2023-01-01 04:00      0.0  2023-01-01           0.0
# ...     ...   ...               ...      ...         ...           ...
# ...

# %%
df_3mm = df[df['강수량(mm)'] >= 3]
df_3mm
# Out:
#          지점   지점명                일시  강수량(mm)          날짜  cum_rainfall
# 4601    400    강남  2023-01-13 02:00      3.0  2023-01-13           3.0
# 4602    400    강남  2023-01-13 03:00      3.5  2023-01-13           6.5
# 4606    400    강남  2023-01-13 07:00     10.0  2023-01-13          22.0
# 4607    400    강남  2023-01-13 08:00      7.0  2023-01-13          29.0
# 4608    400    강남  2023-01-13 09:00      4.5  2023-01-13          33.5
# ...     ...   ...               ...      ...         ...           ...
# 116712  510  영등포   2023-06-26 23:00      3.0  2023-06-26          27.0
# 116770  510  영등포   2023-06-29 09:00      5.0  2023-06-29           5.0
# 116772  510  영등포   2023-06-29 11:00     16.0  2023-06-29          22.5
# 116773  510  영등포   2023-06-29 12:00     26.0  2023-06-29          48.5
# 116777  510  영등포   2023-06-29 16:00     13.0  2023-06-29          66.0
#
# [1189 rows x 6 columns]

# %%
df_fin = df_3mm.drop_duplicates(subset=['지점명', '날짜'])
df_fin
# Out:
#          지점   지점명                일시  강수량(mm)          날짜  cum_rainfall
# 4601    400    강남  2023-01-13 02:00      3.0  2023-01-13           3.0
# 6551    400    강남  2023-04-04 23:00      4.0  2023-04-04           6.0
# 6552    400    강남  2023-04-05 00:00      3.0  2023-04-05           3.0
# 7130    400    강남  2023-04-29 02:00      4.5  2023-04-29           5.5
# 7292    400    강남  2023-05-05 20:00      5.0  2023-05-05          15.0
# ...     ...   ...               ...      ...         ...           ...
# 116332  510  영등포   2023-06-11 03:00      3.0  2023-06-11           7.0
# 116416  510  영등포   2023-06-14 15:00      5.5  2023-06-14           5.5
# 116569  510  영등포   2023-06-21 00:00      6.0  2023-06-21           6.0
# 116695  510  영등포   2023-06-26 06:00     10.0  2023-06-26          11.0
# 116770  510  영등포   2023-06-29 09:00      5.0  2023-06-29           5.0
#
# [320 rows x 6 columns]

# %%
df['flag'] = 0
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\3030806186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flag'] = 0

# %%
df['일시'] = pd.to_datetime(df['일시'])
df = df[df['일시'].dt.strftime('%H:%M') == '23:00']
df
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\2357555552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['일시'] = pd.to_datetime(df['일시'])
#          지점   지점명                  일시  강수량(mm)          날짜  cum_rainfall  flag
# 4334    400    강남 2023-01-01 23:00:00      0.0  2023-01-01           0.0     0
# 4358    400    강남 2023-01-02 23:00:00      0.0  2023-01-02           0.0     0
# 4382    400    강남 2023-01-03 23:00:00      0.0  2023-01-03           0.0     0
# 4406    400    강남 2023-01-04 23:00:00      0.0  2023-01-04           0.0     0
# 4430    400    강남 2023-01-05 23:00:00      0.0  2023-01-05           0.0     0
# ...     ...   ...                 ...      ...         ...           ...   ...
# ...

# %%
df[df['cum_rainfall'] > 0]
# Out:
#          지점   지점명                  일시  강수량(mm)          날짜  cum_rainfall  flag
# 4454    400    강남 2023-01-06 23:00:00      1.0  2023-01-06           1.5     0
# 4478    400    강남 2023-01-07 23:00:00      0.0  2023-01-07           2.5     0
# 4622    400    강남 2023-01-13 23:00:00      0.0  2023-01-13          35.0     0
# 4646    400    강남 2023-01-14 23:00:00      0.0  2023-01-14           3.5     0
# 4670    400    강남 2023-01-15 23:00:00      0.0  2023-01-15           5.5     0
# ...     ...   ...                 ...      ...         ...           ...   ...
# 116592  510  영등포  2023-06-21 23:00:00      0.0  2023-06-21          29.0     0
# 116712  510  영등포  2023-06-26 23:00:00      3.0  2023-06-26          27.0     0
# 116736  510  영등포  2023-06-27 23:00:00      0.0  2023-06-27           1.0     0
# 116784  510  영등포  2023-06-29 23:00:00      0.0  2023-06-29          67.5     0
# 116808  510  영등포  2023-06-30 23:00:00      0.0  2023-06-30           0.5     0
#
# [792 rows x 7 columns]

# %%
df_fin = df_fin[['지점명', '날짜']]
df_fin
# Out:
#          지점명          날짜
# 4601      강남  2023-01-13
# 6551      강남  2023-04-04
# 6552      강남  2023-04-05
# 7130      강남  2023-04-29
# 7292      강남  2023-05-05
# ...      ...         ...
# 116332  영등포   2023-06-11
# 116416  영등포   2023-06-14
# 116569  영등포   2023-06-21
# 116695  영등포   2023-06-26
# 116770  영등포   2023-06-29
#
# [320 rows x 2 columns]

# %%
df
# Out:
#          지점   지점명                  일시  강수량(mm)          날짜  cum_rainfall  flag
# 4334    400    강남 2023-01-01 23:00:00      0.0  2023-01-01           0.0     0
# 4358    400    강남 2023-01-02 23:00:00      0.0  2023-01-02           0.0     0
# 4382    400    강남 2023-01-03 23:00:00      0.0  2023-01-03           0.0     0
# 4406    400    강남 2023-01-04 23:00:00      0.0  2023-01-04           0.0     0
# 4430    400    강남 2023-01-05 23:00:00      0.0  2023-01-05           0.0     0
# ...     ...   ...                 ...      ...         ...           ...   ...
# 116712  510  영등포  2023-06-26 23:00:00      3.0  2023-06-26          27.0     0
# 116736  510  영등포  2023-06-27 23:00:00      0.0  2023-06-27           1.0     0
# 116760  510  영등포  2023-06-28 23:00:00      0.0  2023-06-28           0.0     0
# 116784  510  영등포  2023-06-29 23:00:00      0.0  2023-06-29          67.5     0
# 116808  510  영등포  2023-06-30 23:00:00      0.0  2023-06-30           0.5     0
#
# [4136 rows x 7 columns]

# %%
df[df['cum_rainfall'] > 0]
# Out:
#          지점   지점명                  일시  강수량(mm)          날짜  cum_rainfall  flag
# 4454    400    강남 2023-01-06 23:00:00      1.0  2023-01-06           1.5     0
# 4478    400    강남 2023-01-07 23:00:00      0.0  2023-01-07           2.5     0
# 4622    400    강남 2023-01-13 23:00:00      0.0  2023-01-13          35.0     0
# 4646    400    강남 2023-01-14 23:00:00      0.0  2023-01-14           3.5     0
# 4670    400    강남 2023-01-15 23:00:00      0.0  2023-01-15           5.5     0
# ...     ...   ...                 ...      ...         ...           ...   ...
# 116592  510  영등포  2023-06-21 23:00:00      0.0  2023-06-21          29.0     0
# 116712  510  영등포  2023-06-26 23:00:00      3.0  2023-06-26          27.0     0
# 116736  510  영등포  2023-06-27 23:00:00      0.0  2023-06-27           1.0     0
# 116784  510  영등포  2023-06-29 23:00:00      0.0  2023-06-29          67.5     0
# 116808  510  영등포  2023-06-30 23:00:00      0.0  2023-06-30           0.5     0
#
# [792 rows x 7 columns]

# %%
df['flag'] = df.apply(lambda row: 1 if (row['지점명'], row['날짜']) in zip(df_fin['지점명'], df_fin['날짜']) else row['flag'], axis=1)
df
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\679207452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flag'] = df.apply(lambda row: 1 if (row['지점명'], row['날짜']) in zip(df_fin['지점명'], df_fin['날짜']) else row['flag'], axis=1)
#          지점   지점명                  일시  강수량(mm)          날짜  cum_rainfall  flag
# 4334    400    강남 2023-01-01 23:00:00      0.0  2023-01-01           0.0     0
# 4358    400    강남 2023-01-02 23:00:00      0.0  2023-01-02           0.0     0
# 4382    400    강남 2023-01-03 23:00:00      0.0  2023-01-03           0.0     0
# 4406    400    강남 2023-01-04 23:00:00      0.0  2023-01-04           0.0     0
# 4430    400    강남 2023-01-05 23:00:00      0.0  2023-01-05           0.0     0
# ...

# %%
len(df[df['flag'] == 1])
# Out:
# 320

# %%
df = df[['지점명', '날짜', 'cum_rainfall' ,'flag']]
df
# Out:
#          지점명          날짜  cum_rainfall  flag
# 4334      강남  2023-01-01           0.0     0
# 4358      강남  2023-01-02           0.0     0
# 4382      강남  2023-01-03           0.0     0
# 4406      강남  2023-01-04           0.0     0
# 4430      강남  2023-01-05           0.0     0
# ...      ...         ...           ...   ...
# 116712  영등포   2023-06-26          27.0     1
# 116736  영등포   2023-06-27           1.0     0
# 116760  영등포   2023-06-28           0.0     0
# 116784  영등포   2023-06-29          67.5     1
# 116808  영등포   2023-06-30           0.5     0
#
# [4136 rows x 4 columns]

# %%
df['날짜'] = pd.to_datetime(df['날짜'])
df[df['날짜'].dt.date == pd.to_datetime('2018-04-10').date()]
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\2713312092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['날짜'] = pd.to_datetime(df['날짜'])
# Empty DataFrame
# Columns: [지점명, 날짜, cum_rainfall, flag]
# Index: []

# %%
df[df['cum_rainfall'] > 0]
# Out:
#          지점명         날짜  cum_rainfall  flag
# 4454      강남 2023-01-06           1.5     0
# 4478      강남 2023-01-07           2.5     0
# 4622      강남 2023-01-13          35.0     1
# 4646      강남 2023-01-14           3.5     0
# 4670      강남 2023-01-15           5.5     0
# ...      ...        ...           ...   ...
# 116592  영등포  2023-06-21          29.0     1
# 116712  영등포  2023-06-26          27.0     1
# 116736  영등포  2023-06-27           1.0     0
# 116784  영등포  2023-06-29          67.5     1
# 116808  영등포  2023-06-30           0.5     0
#
# [792 rows x 4 columns]

# %% [markdown]
# 비가 오긴 한 날 792, 한 시간에 3mm이상 온 날: 320개

# %%
df
# Out:
#          지점명         날짜  cum_rainfall  flag
# 4334      강남 2023-01-01           0.0     0
# 4358      강남 2023-01-02           0.0     0
# 4382      강남 2023-01-03           0.0     0
# 4406      강남 2023-01-04           0.0     0
# 4430      강남 2023-01-05           0.0     0
# ...      ...        ...           ...   ...
# 116712  영등포  2023-06-26          27.0     1
# 116736  영등포  2023-06-27           1.0     0
# 116760  영등포  2023-06-28           0.0     0
# 116784  영등포  2023-06-29          67.5     1
# 116808  영등포  2023-06-30           0.5     0
#
# [4136 rows x 4 columns]

# %%
data
# Out:
#      측정소명      년/월/일   회차  수온(℃)  DO(㎎/L)  BOD(㎎/L)  COD(㎎/L)  TP(㎎/L)  \
# 0      구의 2023-01-02  1회차    NaN      NaN       NaN       NaN      NaN
# 1     노량진 2023-01-02  1회차    2.0     13.6       1.5       4.5    0.042
# 2    안양천9 2023-01-02  1회차    NaN      NaN       NaN       NaN      NaN
# 3    중랑천3 2023-01-02  1회차    NaN      NaN       NaN       NaN      NaN
# 4      가양 2023-01-03  1회차    NaN      NaN       NaN       NaN      NaN
# ..    ...        ...  ...    ...      ...       ...       ...      ...
# 226   초이천 2023-04-24  4회차   19.5     12.3       2.0       5.4    0.132
# 227    구의 2023-04-27  4회차   14.8     10.5       1.3       3.6    0.024
# 228   노량진 2023-04-27  4회차   16.4      9.6       2.0       4.5    0.048
# 229  안양천9 2023-04-27  4회차   16.4      8.6       3.9       9.0    0.165
# 230  중랑천3 2023-04-27  4회차   19.4     10.1       2.2       7.1    0.144
#
#      TOC(㎎/L)  수소이온농도  SS(㎎/L)  pollution_score
# 0         NaN     NaN      NaN                6
# ...

# %%
data['pollution_score'].unique()
# Out:
# array([6, 0, 1, 2, 3, 4], dtype=int64)

# %%
data2 = data[data['측정소명'].isin(['가양', '노량진'])]

# %%
data2['pollution_score'].unique()
# Out:
# array([0, 6, 1], dtype=int64)

# %%
data['자치구']=0
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\3025801739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['자치구']=0

# %%
data
# Out:
#      측정소명      년/월/일   회차  수온(℃)  DO(㎎/L)  BOD(㎎/L)  COD(㎎/L)  TP(㎎/L)  \
# 0      구의 2023-01-02  1회차    NaN      NaN       NaN       NaN      NaN
# 1     노량진 2023-01-02  1회차    2.0     13.6       1.5       4.5    0.042
# 2    안양천9 2023-01-02  1회차    NaN      NaN       NaN       NaN      NaN
# 3    중랑천3 2023-01-02  1회차    NaN      NaN       NaN       NaN      NaN
# 4      가양 2023-01-03  1회차    NaN      NaN       NaN       NaN      NaN
# ..    ...        ...  ...    ...      ...       ...       ...      ...
# 226   초이천 2023-04-24  4회차   19.5     12.3       2.0       5.4    0.132
# 227    구의 2023-04-27  4회차   14.8     10.5       1.3       3.6    0.024
# 228   노량진 2023-04-27  4회차   16.4      9.6       2.0       4.5    0.048
# 229  안양천9 2023-04-27  4회차   16.4      8.6       3.9       9.0    0.165
# 230  중랑천3 2023-04-27  4회차   19.4     10.1       2.2       7.1    0.144
#
#      TOC(㎎/L)  수소이온농도  SS(㎎/L)  pollution_score  자치구
# 0         NaN     NaN      NaN                6    0
# ...

# %%
data['측정소명'].nunique() #33
data['측정소명'].value_counts()
# Out:
# 구의       17
# 노량진      17
# 안양천9     17
# 중랑천3     17
# 가양       17
# 초이천      10
# 양재천1     10
# 망월천      10
# 감이천      10
# 목감천2      9
# 안양천8      9
# 양재천2      4
# 우이천       4
# 고덕천       4
# 도림천       4
# 목감천1      4
# 성내천       4
# 성북천       4
# 잠실        4
# 영등포       4
# 암사        4
# 보광        4
# 뚝도        4
# 홍제천       4
# 탄천6       4
# 청계천3      4
# 청계천2      4
# 청계천1      4
# 안양천10     4
# 중랑천5      4
# 중랑천4      4
# 정릉천       4
# 중랑천6      4
# Name: 측정소명, dtype: int64

# %%
data.loc[data['측정소명'] == '가양', '자치구'] = '강서구'
data.loc[data['측정소명'].isin(['보광','노량진']), '자치구'] = '용산구'
data.loc[data['측정소명'].isin(['성내천','고덕천','망월천','초이천','구의','암사']), '자치구'] = '강동구'
data.loc[data['측정소명'].isin(['목감천1', '목감천2', '안양천8', '안양천9']), '자치구'] = '구로구'
data.loc[data['측정소명'].isin(['성북천', '정릉천', '중랑천5']), '자치구'] = '동대문구'
#15개
data.loc[data['측정소명'].isin(['안양천10']), '자치구'] = '양천구'
data.loc[data['측정소명'].isin(['중랑천3', ]), '자치구'] = '도봉구'
data.loc[data['측정소명'].isin(['양재천2','탄천6']), '자치구'] = '강남구'
data.loc[data['측정소명'].isin(['청계천2', '청계천3', '중랑천6','뚝도']), '자치구'] = '성동구'
data.loc[data['측정소명'].isin(['우이천',]), '자치구'] = '성북구'
data.loc[data['측정소명'].isin(['홍제천']), '자치구'] = '마포구'
data.loc[data['측정소명'].isin(['잠실','감이천']), '자치구'] = '송파구'
#26개                            
data.loc[data['측정소명'].isin(['양재천1']), '자치구'] = '서초구'
#28개
data.loc[data['측정소명'].isin(['도림천']), '자치구'] = '동작구'
#30개
data.loc[data['측정소명'].isin(['중랑천4']), '자치구'] = '노원구'
data.loc[data['측정소명'].isin(['영등포']), '자치구'] = '영등포구'
data.loc[data['측정소명'].isin(['청계천1']), '자치구'] = '중구'

# %%
data.rename(columns={'년/월/일': '날짜'}, inplace = True)
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\239013938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={'년/월/일': '날짜'}, inplace = True)

# %%
df['지점명'] = df['지점명'] + '구'
df['지점명'] = df['지점명'].str.replace(' ', '')
df
#df['지점명'] = df['지점명'].str.replace('중구구', '중구')
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\2728214839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['지점명'] = df['지점명'] + '구'
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\2728214839.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['지점명'] = df['지점명'].str.replace(' ', '')
#          지점명         날짜  cum_rainfall  flag
# 4334     강남구 2023-01-01           0.0     0
# 4358     강남구 2023-01-02           0.0     0
# 4382     강남구 2023-01-03           0.0     0
# ...

# %%
df['지점명'].value_counts()
# Out:
# 강북구     181
# 송파구     181
# 도봉구     181
# 노원구     181
# 동대문구    181
# 마포구     181
# 용산구     181
# 강남구     180
# 광진구     180
# 구로구     180
# 성동구     180
# 금천구     180
# 서대문구    180
# 서초구     180
# 중랑구     180
# 강동구     180
# 영등포구    180
# 은평구     179
# 중구구     179
# 양천구     179
# 강서구     179
# 관악구     177
# 성북구     176
# Name: 지점명, dtype: int64

# %%
df['지점명'] = df['지점명'].str.replace('중구구', '중구')
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\2652967805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['지점명'] = df['지점명'].str.replace('중구구', '중구')

# %%
df['지점명'].unique()
# Out:
# array(['강남구', '서초구', '강동구', '송파구', '강서구', '양천구', '도봉구', '노원구', '동대문구',
#        '중랑구', '마포구', '서대문구', '광진구', '성북구', '용산구', '은평구', '금천구', '중구',
#        '성동구', '구로구', '강북구', '관악구', '영등포구'], dtype=object)

# %%
data['날짜'] = pd.to_datetime(data['날짜'])
df['날짜'] = pd.to_datetime(df['날짜'])
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\2143929551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['날짜'] = pd.to_datetime(data['날짜'])
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\2143929551.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['날짜'] = pd.to_datetime(df['날짜'])

# %%
df
# Out:
#          지점명         날짜  cum_rainfall  flag
# 4334     강남구 2023-01-01           0.0     0
# 4358     강남구 2023-01-02           0.0     0
# 4382     강남구 2023-01-03           0.0     0
# 4406     강남구 2023-01-04           0.0     0
# 4430     강남구 2023-01-05           0.0     0
# ...      ...        ...           ...   ...
# 116712  영등포구 2023-06-26          27.0     1
# 116736  영등포구 2023-06-27           1.0     0
# 116760  영등포구 2023-06-28           0.0     0
# 116784  영등포구 2023-06-29          67.5     1
# 116808  영등포구 2023-06-30           0.5     0
#
# [4136 rows x 4 columns]

# %%
merged_df = pd.merge(data, df, left_on=['자치구', '날짜'], right_on=['지점명', '날짜'], how='left')
merged_df
# Out:
#      측정소명         날짜   회차  수온(℃)  DO(㎎/L)  BOD(㎎/L)  COD(㎎/L)  TP(㎎/L)  \
# 0      구의 2023-01-02  1회차    NaN      NaN       NaN       NaN      NaN
# 1     노량진 2023-01-02  1회차    2.0     13.6       1.5       4.5    0.042
# 2    안양천9 2023-01-02  1회차    NaN      NaN       NaN       NaN      NaN
# 3    중랑천3 2023-01-02  1회차    NaN      NaN       NaN       NaN      NaN
# 4      가양 2023-01-03  1회차    NaN      NaN       NaN       NaN      NaN
# ..    ...        ...  ...    ...      ...       ...       ...      ...
# 226   초이천 2023-04-24  4회차   19.5     12.3       2.0       5.4    0.132
# 227    구의 2023-04-27  4회차   14.8     10.5       1.3       3.6    0.024
# 228   노량진 2023-04-27  4회차   16.4      9.6       2.0       4.5    0.048
# 229  안양천9 2023-04-27  4회차   16.4      8.6       3.9       9.0    0.165
# 230  중랑천3 2023-04-27  4회차   19.4     10.1       2.2       7.1    0.144
#
#      TOC(㎎/L)  수소이온농도  SS(㎎/L)  pollution_score  자치구  cum_rainfall_x  flag_x  \
# ...

# %%
merged_df['flag_y'].value_counts()
# Out:
# 0.0    220
# 1.0      7
# Name: flag_y, dtype: int64

# %%
data['cum_rainfall'] = merged_df['cum_rainfall_y']
data['flag'] = merged_df['flag_y']
data
# Out:
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\3647079957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cum_rainfall'] = merged_df['cum_rainfall_y']
# C:\Users\youngseolee\AppData\Local\Temp\ipykernel_9816\3647079957.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['flag'] = merged_df['flag_y']
#      측정소명         날짜   회차  수온(℃)  DO(㎎/L)  BOD(㎎/L)  COD(㎎/L)  TP(㎎/L)  \
# 0      구의 2023-01-02  1회차    NaN      NaN       NaN       NaN      NaN
# ...

# %%
data.isnull().sum()
# Out:
# 측정소명                0
# 날짜                  0
# 회차                  0
# 수온(℃)              22
# DO(㎎/L)            22
# BOD(㎎/L)           22
# COD(㎎/L)           22
# TP(㎎/L)            22
# TOC(㎎/L)           22
# 수소이온농도             22
# SS(㎎/L)            22
# pollution_score     0
# 자치구                 0
# cum_rainfall        4
# flag                4
# dtype: int64

# %%
new_df = data.drop([0, 2, 3, 4,6])

# %%
new_df.isnull().sum()
# Out:
# 측정소명                0
# 날짜                  0
# 회차                  0
# 수온(℃)              18
# DO(㎎/L)            18
# BOD(㎎/L)           18
# COD(㎎/L)           18
# TP(㎎/L)            18
# TOC(㎎/L)           18
# 수소이온농도             18
# SS(㎎/L)            18
# pollution_score     0
# 자치구                 0
# cum_rainfall        3
# flag                3
# dtype: int64

# %%
new_df.dropna(inplace=True)

# %%
unique_gu = new_df['자치구'].unique()

gu_dataframes = {}  # 자치구별 데이터프레임을 저장할 딕셔너리

for gu in unique_gu:
    gu_dataframes[gu] = new_df[new_df['자치구'] == gu].copy()

# %%
df_guro=gu_dataframes['구로구']
df_guro
# Out:
#      측정소명         날짜   회차  수온(℃)  DO(㎎/L)  BOD(㎎/L)  COD(㎎/L)  TP(㎎/L)  \
# 7    목감천1 2023-01-05  1회차    4.9     13.0       2.1       5.9    0.094
# 30   안양천9 2023-01-12  2회차   10.0     11.5       3.0       8.9    0.111
# 40   목감천2 2023-01-19  1회차    5.5     11.4       2.3       5.1    0.087
# 41   안양천8 2023-01-19  1회차    8.9     11.0       3.2       8.3    0.030
# 55   목감천1 2023-02-02  1회차    4.9     12.5       2.6       6.0    0.113
# 87   안양천9 2023-02-16  2회차    8.4     10.2       4.6       9.1    0.126
# 89   목감천2 2023-02-17  1회차    8.9     12.0       3.4       6.5    0.109
# 90   안양천8 2023-02-17  1회차   13.2     12.7       3.7       9.5    0.045
# 96   목감천2 2023-02-23  2회차    9.7     11.6       2.7       6.8    0.126
# 97   안양천8 2023-02-23  2회차   12.5     12.6       3.5      10.6    0.031
# 100  안양천9 2023-02-23  3회차    8.5     10.3       4.2       9.5    0.129
# 109  목감천1 2023-03-02  1회차    9.4     11.5       2.3       6.7    0.168
# ...

# %%
df_guro['PM10']=0
df_guro
# Out:
#      측정소명         날짜   회차  수온(℃)  DO(㎎/L)  BOD(㎎/L)  COD(㎎/L)  TP(㎎/L)  \
# 7    목감천1 2023-01-05  1회차    4.9     13.0       2.1       5.9    0.094
# 30   안양천9 2023-01-12  2회차   10.0     11.5       3.0       8.9    0.111
# 40   목감천2 2023-01-19  1회차    5.5     11.4       2.3       5.1    0.087
# 41   안양천8 2023-01-19  1회차    8.9     11.0       3.2       8.3    0.030
# 55   목감천1 2023-02-02  1회차    4.9     12.5       2.6       6.0    0.113
# 87   안양천9 2023-02-16  2회차    8.4     10.2       4.6       9.1    0.126
# 89   목감천2 2023-02-17  1회차    8.9     12.0       3.4       6.5    0.109
# 90   안양천8 2023-02-17  1회차   13.2     12.7       3.7       9.5    0.045
# 96   목감천2 2023-02-23  2회차    9.7     11.6       2.7       6.8    0.126
# 97   안양천8 2023-02-23  2회차   12.5     12.6       3.5      10.6    0.031
# 100  안양천9 2023-02-23  3회차    8.5     10.3       4.2       9.5    0.129
# 109  목감천1 2023-03-02  1회차    9.4     11.5       2.3       6.7    0.168
# ...

# %%
df_guro['PM10']=[57,75,66,66,46,29,47,47,42,42,42,63,60,60,60,74,74,74,140,157,157,101,75,75,75,217,94,94,94,22,67,67,40]

# %%
df_guro_fin = df_guro[df_guro['측정소명'] =='안양천9']

# %%
df_guroFin = df_guro_fin[['날짜','수온(℃)','cum_rainfall','PM10','수소이온농도','pollution_score']]

# %%
df_guroFin.to_csv("test_anyang9.csv",index= False)
